# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = loadtxt("datos.dat")
plot(a)

# %%
c = zeros(len(a))
for i in range(len(a)-1):
    c[i] = abs(a[i+1]-a[i])

# %%
plot(log(c))
