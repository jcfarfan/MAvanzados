# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = loadtxt("oscilador.dat")
x = a[:,0]
y = a[:,1]

# %%
plot(x,y)
xlim(0,100)
# Out:
# (0, 100)

# %%
a = loadtxt("oscilador.dat")
x = a[:,0]
y = a[:,1]

# %%
plot(x,y)
xlim(0,100)
# Out:
# (0, 100)

# %%
a = loadtxt("oscilador.dat")
x = a[:,0]
y = a[:,1]

# %%
plot(x,y)
xlim(0,100)
# Out:
# (0, 100)
